# %% [markdown]
# <a href="https://colab.research.google.com/github/animesh-19/MLPC-INDIVIDUAL-ASSIGNMENT/blob/main/MLPC_INDIVIDUAL_ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Individual Assignment of Machine Learning**

# %% [markdown]
# **1. Importing the Required Python Libraries**

# %%
# Data Handling & Manipulation
import pandas as pd         # For loading, exploring, and manipulating datasets
import numpy as np          # For numerical operations and array handling

# Data Visualization
import matplotlib.pyplot as plt     # Standard plotting library for 2D charts
import seaborn as sns               # Statistical data visualization (heatmaps, boxplots, etc.)
import plotly.express as px         # Interactive plotting library, simple high-level API
import plotly.graph_objects as go   # Detailed and customizable interactive plots
from plotly.subplots import make_subplots  # To create multi-plot figures in Plotly

# Machine Learning & Preprocessing

from sklearn.preprocessing import MinMaxScaler       # Normalize/scale features to [0,1] range
from sklearn.model_selection import train_test_split  # Split dataset into training and testing sets
from sklearn.linear_model import LinearRegression    # Linear Regression model for prediction
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Metrics to evaluate model performance:
# - MAE: Mean Absolute Error
# - MSE: Mean Squared Error
# - R²: Coefficient of Determination (goodness-of-fit)

# %% [markdown]
# **2. Importing the Given CSV Dataset**

# %%
# Loading datasets from Google Drive

dfa = pd.read_csv("/content/drive/MyDrive/Mlpc/cotton_production.csv")       # Cotton production data
dfb = pd.read_csv("/content/drive/MyDrive/Mlpc/horses_population.csv")       # Horses population data
dfc = pd.read_csv("/content/drive/MyDrive/Mlpc/milk_production.csv")         # Milk production data
dfd = pd.read_csv("/content/drive/MyDrive/Mlpc/meat_production.csv")         # Meat production data
dfe = pd.read_csv("/content/drive/MyDrive/Mlpc/egg_production.csv")          # Egg production data
dff = pd.read_csv("/content/drive/MyDrive/Mlpc/rabbit_population.csv")       # Rabbit population data
dfg = pd.read_csv("/content/drive/MyDrive/Mlpc/wool_production.csv")         # Wool production data
dfh = pd.read_csv("/content/drive/MyDrive/Mlpc/yak_population.csv")          # Yak population data

# %% [markdown]
# **3. Exploration of Each Datasets**

# %%
print("production of cotton: ")
display(dfa.head(5))
print("population of horse:")
display(dfb.head(5))
print("production of milk: ")
display(dfc.head(5))
print("Production of meat: ")
display(dfd.head(5))
print("production of wool: ")
display(dfe.head(5))
print("population of rabbit: ")
display(dff.head(5))
print("production of egg: ")
display(dfg.head(5))
print("population of chauri: ")
display(dfh.head(5))
# Out:
# production of cotton:
#   DISTRICT  AREA (Ha.)  PROD. (Mt.)  YIELD Kg/Ha
# 0     Dang         106           74          700
# 1    Banke          27           41         1519
# 2  Bardiya          10           12         1200
# 3    NEPAL         143          127          890
# population of horse:
#         DISTRICT  Horses/Asses
# 0      TAPLEJUNG           543
# 1  SANKHUWASHAVA           358
# 2     SOLUKHUMBU          1775
# 3      PANCHTHAR            15
# 4          ILLAM          2815
# production of milk:
#         DISTRICT  MILKING  COWS NO.  MILKING  BUFFALOES NO.  COW MILK  \
# 0      TAPLEJUNG               8123                    4987      5389
# 1  SANKHUWASHAVA              15342                   13367      6988
# 2     SOLUKHUMBU               7819                   13501      2948
# 3     E.MOUNTAIN              31284                   31855     15324
# 4      PANCHTHAR              14854                   11331      8511
#
#    BUFF MILK  TOTAL MILK PRODUCED
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **4. Display of Datasets Statistics**

# %% [markdown]
# **4.1. Stats  of Cotton**

# %%
dfa.describe()
# Out:
#        AREA (Ha.)  PROD. (Mt.)  YIELD Kg/Ha
# count    4.000000     4.000000     4.000000
# mean    71.500000    63.500000  1077.250000
# std     63.416612    49.332207   359.439726
# min     10.000000    12.000000   700.000000
# 25%     22.750000    33.750000   842.500000
# 50%     66.500000    57.500000  1045.000000
# 75%    115.250000    87.250000  1279.750000
# max    143.000000   127.000000  1519.000000

# %%
dfa.isnull().sum()
# Out:
# DISTRICT       0
# AREA (Ha.)     0
# PROD. (Mt.)    0
# YIELD Kg/Ha    0
# dtype: int64

# %% [markdown]
# **4.2.Stats of Horses**

# %%
dfb.describe()
# Out:
#        Horses/Asses
# count     60.000000
# mean    2790.400000
# std     8447.864779
# min       12.000000
# 25%      122.250000
# 50%      493.000000
# 75%     1510.250000
# max    55808.000000

# %%
dfb.isnull().sum()
# Out:
# DISTRICT        0
# Horses/Asses    0
# dtype: int64

# %% [markdown]
# **4.3. Stats of Milk**

# %%
dfc.describe()
# Out:
#        MILKING  COWS NO.  MILKING  BUFFALOES NO.       COW MILK     BUFF MILK  \
# count       9.600000e+01            9.600000e+01      96.000000  9.600000e+01
# mean        4.275562e+04            5.647433e+04   26825.260417  5.043505e+04
# std         1.144496e+05            1.508551e+05   71948.998086  1.358044e+05
# min         4.520000e+02            0.000000e+00     259.000000  0.000000e+00
# 25%         8.074750e+03            1.020550e+04    4630.750000  9.085000e+03
# 50%         1.513050e+04            1.954000e+04    8343.500000  1.710250e+04
# 75%         2.600800e+04            3.674975e+04   15694.000000  3.110500e+04
# max         1.026135e+06            1.355384e+06  643806.000000  1.210441e+06
#
#        TOTAL MILK PRODUCED
# count            95.000000
# mean          58555.189474
# std           96696.838132
# min             259.000000
# 25%           14179.500000
# 50%           28027.000000
# 75%           43324.000000
# max          536299.000000

# %%
dfc.isnull().sum()
# Out:
# DISTRICT                  0
# MILKING  COWS NO.         0
# MILKING  BUFFALOES NO.    0
# COW MILK                  0
# BUFF MILK                 0
# TOTAL MILK PRODUCED       1
# dtype: int64

# %% [markdown]
# **4.4. Stats of Meat**

# %%
dfd.describe()
# Out:
#                BUFF       MUTTON        CHEVON         PORK        CHICKEN  \
# count      96.00000    96.000000     96.000000     96.000000     96.000000
# mean     7291.87500   111.833333   2732.625000    979.541667   2293.375000
# std     19484.37418   314.001598   7245.635676   2713.977477   6645.981822
# min         0.00000     0.000000     56.000000      1.000000      5.000000
# 25%      1438.50000    10.000000    575.000000    114.000000    208.250000
# 50%      2558.00000    31.000000    890.000000    326.000000    489.000000
# 75%      4447.00000    90.750000   1689.500000    711.250000   1615.250000
# max    175005.00000  2684.000000  65583.000000  23509.000000  55041.000000
#
#         DUCK MEAT     TOTAL MEAT
# count   96.000000      96.000000
# mean     9.875000   13419.125000
# std     28.561015   35967.078276
# min      0.000000      78.000000
# 25%      0.000000    2771.000000
# 50%      2.000000    4502.000000
# 75%      6.000000    7827.500000
# ...

# %%
dfd.isnull().sum()
# Out:
# DISTRICT      0
# BUFF          0
# MUTTON        0
# CHEVON        0
# PORK          0
# CHICKEN       0
# DUCK MEAT     0
# TOTAL MEAT    0
# dtype: int64

# %% [markdown]
# **4.5.Stats of Wool**

# %%
dfe.describe()
# Out:
#          LAYING HEN    LAYING DUCK       HEN EGG      DUCK EGG     TOTAL EGG
# count  9.600000e+01      96.000000  9.600000e+01     96.000000  9.600000e+01
# mean   5.147298e+05    7538.625000  5.392358e+04    579.416667  5.450300e+04
# std    1.536131e+06   21446.360692  1.650960e+05   1649.968112  1.665308e+05
# min    1.488000e+03       3.000000  2.100000e+02      0.000000  2.110000e+02
# 25%    3.319350e+04     317.750000  3.060750e+03     24.750000  3.099000e+03
# 50%    1.113675e+05    1422.500000  7.769500e+03    109.500000  7.978500e+03
# 75%    3.037330e+05    4475.500000  3.172875e+04    326.250000  3.259750e+04
# max    1.235352e+07  180927.000000  1.294166e+06  13906.000000  1.308072e+06

# %%
dfe.isnull().sum()
# Out:
# DISTRICT       0
# LAYING HEN     0
# LAYING DUCK    0
# HEN EGG        0
# DUCK EGG       0
# TOTAL EGG      0
# dtype: int64

# %% [markdown]
# **4.6. Stats of Rabbit**

# %%
dff.describe()
# Out:
#              Rabbit
# count     55.000000
# mean    1757.072727
# std     4684.882317
# min       19.000000
# 25%      179.000000
# 50%      506.000000
# 75%     1135.500000
# max    32213.000000

# %%
dff.isnull().sum()
# Out:
# DISTRICT    0
# Rabbit      0
# dtype: int64

# %% [markdown]
# **4.7. Stats of Eggs**

# %%
dfg.describe()
# Out:
#           SHEEPS NO.  SHEEP WOOL PRODUCED
# count      96.000000            96.000000
# mean    33360.750000         24514.500000
# std     94126.278004         69318.271646
# min        36.000000            13.000000
# 25%      2637.500000          1958.750000
# 50%      9130.500000          6414.500000
# 75%     26427.250000         19054.500000
# max    800658.000000        588348.000000

# %%
dfg.isnull().sum()
# Out:
# DISTRICT               0
# SHEEPS NO.             0
# SHEEP WOOL PRODUCED    0
# dtype: int64

# %% [markdown]
#  **4.8. Stats of Chauri**

# %%
dfh.describe()
# Out:
#        YAK/NAK/CHAURI
# count        35.00000
# mean       5899.80000
# std       12300.08377
# min          25.00000
# 25%         407.00000
# 50%        1075.00000
# 75%        5556.00000
# max       68831.00000

# %%
dfh.isnull().sum()
# Out:
# DISTRICT          0
# YAK/NAK/CHAURI    0
# dtype: int64

# %% [markdown]
# **5. Merge the Dataset**

# %%
dfs = [dfa, dfb, dfc, dfd, dfe, dff, dfg, dfh]
# Merge dataframes using outer join
merged_df = pd.merge(dfs[0], dfs[1], on='DISTRICT', how='outer')
for df in dfs[2:]:
    merged_df = pd.merge(merged_df, df, on='DISTRICT', how='outer')

# %%
merged_df
# Out:
#           DISTRICT  AREA (Ha.)  PROD. (Mt.)  YIELD Kg/Ha  Horses/Asses  \
# 0           ACHHAM         NaN          NaN          NaN          95.0
# 1     ARGHAKHANCHI         NaN          NaN          NaN          17.0
# 2          BAGLUNG         NaN          NaN          NaN        1250.0
# 3          BAITADI         NaN          NaN          NaN         484.0
# 4          BAJHANG         NaN          NaN          NaN         724.0
# 5           BAJURA         NaN          NaN          NaN        1262.0
# 6            BANKE         NaN          NaN          NaN        3963.0
# 7             BARA         NaN          NaN          NaN         305.0
# 8          BARDIYA         NaN          NaN          NaN         559.0
# 9        BHAKTAPUR         NaN          NaN          NaN           NaN
# 10         BHOJPUR         NaN          NaN          NaN         168.0
# 11           Banke        27.0         41.0       1519.0           NaN
# ...

# %% [markdown]
# **6  Displaying All Rows**

# %%
pd.set_option("display.max_rows", None)
merged_df
# Out:
#           DISTRICT  AREA (Ha.)  PROD. (Mt.)  YIELD Kg/Ha  Horses/Asses  \
# 0           ACHHAM         NaN          NaN          NaN          95.0
# 1     ARGHAKHANCHI         NaN          NaN          NaN          17.0
# 2          BAGLUNG         NaN          NaN          NaN        1250.0
# 3          BAITADI         NaN          NaN          NaN         484.0
# 4          BAJHANG         NaN          NaN          NaN         724.0
# 5           BAJURA         NaN          NaN          NaN        1262.0
# 6            BANKE         NaN          NaN          NaN        3963.0
# 7             BARA         NaN          NaN          NaN         305.0
# 8          BARDIYA         NaN          NaN          NaN         559.0
# 9        BHAKTAPUR         NaN          NaN          NaN           NaN
# 10         BHOJPUR         NaN          NaN          NaN         168.0
# 11           Banke        27.0         41.0       1519.0           NaN
# ...

# %% [markdown]
# **7. Summary of Dataset**

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DISTRICT                108 non-null    object
#  1   AREA (Ha.)              4 non-null      float64
#  2   PROD. (Mt.)             4 non-null      float64
#  3   YIELD Kg/Ha             4 non-null      float64
#  4   Horses/Asses            60 non-null     float64
#  5   MILKING  COWS NO.       96 non-null     float64
#  6   MILKING  BUFFALOES NO.  96 non-null     float64
#  7   COW MILK                96 non-null     float64
#  8   BUFF MILK               96 non-null     float64
#  9   TOTAL MILK PRODUCED     95 non-null     float64
#  10  BUFF                    96 non-null     float64
#  11  MUTTON                  96 non-null     float64
#  12  CHEVON                  96 non-null     float64
#  13  PORK                    96 non-null     float64
# ...

# %%
merged_df.describe()
# Out:
#        AREA (Ha.)  PROD. (Mt.)  YIELD Kg/Ha  Horses/Asses  MILKING  COWS NO.  \
# count    4.000000     4.000000     4.000000     60.000000       9.600000e+01
# mean    71.500000    63.500000  1077.250000   2790.400000       4.275562e+04
# std     63.416612    49.332207   359.439726   8447.864779       1.144496e+05
# min     10.000000    12.000000   700.000000     12.000000       4.520000e+02
# 25%     22.750000    33.750000   842.500000    122.250000       8.074750e+03
# 50%     66.500000    57.500000  1045.000000    493.000000       1.513050e+04
# 75%    115.250000    87.250000  1279.750000   1510.250000       2.600800e+04
# max    143.000000   127.000000  1519.000000  55808.000000       1.026135e+06
#
#        MILKING  BUFFALOES NO.       COW MILK     BUFF MILK  \
# count            9.600000e+01      96.000000  9.600000e+01
# mean             5.647433e+04   26825.260417  5.043505e+04
# std              1.508551e+05   71948.998086  1.358044e+05
# ...

# %%
non_counts = merged_df.isna().sum()
non_counts
# Out:
# DISTRICT                    0
# AREA (Ha.)                104
# PROD. (Mt.)               104
# YIELD Kg/Ha               104
# Horses/Asses               48
# MILKING  COWS NO.          12
# MILKING  BUFFALOES NO.     12
# COW MILK                   12
# BUFF MILK                  12
# TOTAL MILK PRODUCED        13
# BUFF                       12
# MUTTON                     12
# CHEVON                     12
# PORK                       12
# CHICKEN                    12
# DUCK MEAT                  12
# TOTAL MEAT                 12
# LAYING HEN                 12
# LAYING DUCK                12
# HEN EGG                    12
# DUCK EGG                   12
# TOTAL EGG                  12
# Rabbit                     53
# SHEEPS NO.                 12
# SHEEP WOOL PRODUCED        12
# YAK/NAK/CHAURI             73
# dtype: int64

# %%
merged_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %% [markdown]
# **8. View of Duplicate Data**

# %%
merged_df[merged_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [DISTRICT, AREA (Ha.), PROD. (Mt.), YIELD Kg/Ha, Horses/Asses, MILKING  COWS NO., MILKING  BUFFALOES NO., COW MILK, BUFF MILK, TOTAL MILK PRODUCED, BUFF, MUTTON, CHEVON, PORK , CHICKEN, DUCK MEAT, TOTAL MEAT, LAYING HEN, LAYING DUCK, HEN EGG, DUCK EGG, TOTAL EGG, Rabbit, SHEEPS NO., SHEEP WOOL PRODUCED, YAK/NAK/CHAURI]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# **9. Visualization of Data Before Cleaning**

# %%
merged_df.plot(kind = "line")
# Out:
# <Axes: >

# %% [markdown]
# **10. Visualization of Data  Using Heatmap Before Cleaing**

# %%
sns.heatmap(merged_df.isna(), yticklabels = False)
# Out:
# <Axes: >

# %% [markdown]
# **11. Cleaning and Preprocessing of Datasets**

# %%
merged_df.fillna(0, inplace=True)
merged_df.head()
# Out:
#        DISTRICT  AREA (Ha.)  PROD. (Mt.)  YIELD Kg/Ha  Horses/Asses  \
# 0        ACHHAM         0.0          0.0          0.0          95.0
# 1  ARGHAKHANCHI         0.0          0.0          0.0          17.0
# 2       BAGLUNG         0.0          0.0          0.0        1250.0
# 3       BAITADI         0.0          0.0          0.0         484.0
# 4       BAJHANG         0.0          0.0          0.0         724.0
#
#    MILKING  COWS NO.  MILKING  BUFFALOES NO.  COW MILK  BUFF MILK  \
# 0             5796.0                 10381.0    3321.0     9010.0
# 1             6219.0                 27698.0    3805.0    25232.0
# 2             8950.0                 22929.0    5128.0    18093.0
# 3             9845.0                 12699.0    4641.0    10184.0
# 4            15936.0                  9679.0    4600.0     4149.0
#
#    TOTAL MILK PRODUCED  ...  TOTAL MEAT  LAYING HEN  LAYING DUCK  HEN EGG  \
# 0              12331.0  ...      2102.0     12096.0        143.0   1905.0
# ...

# %%
cleaned_df =merged_df

# %%
# Replace spaces with underscores and convert column names to lowercase
cleaned_df.columns = merged_df.columns.str.lower().str.replace(' ', '_')

# Remove double underscores
cleaned_df.columns = merged_df.columns.str.replace('__', '_')

# Remove periods
cleaned_df.columns =merged_df.columns.str.replace('.', '')

# Convert all data in the 'district' column to uppercase
cleaned_df['district'] = merged_df['district'].str.upper()

cleaned_df.sum()
# Out:
# district                ACHHAMARGHAKHANCHIBAGLUNGBAITADIBAJHANGBAJURAB...
# area_(ha)                                                           286.0
# prod_(mt)                                                           254.0
# yield_kg/ha                                                        4309.0
# horses/asses                                                     167424.0
# milking_cows_no                                                 4104540.0
# milking_buffaloes_no                                            5421536.0
# cow_milk                                                        2575225.0
# buff_milk                                                       4841765.0
# total_milk_produced                                             5562743.0
# buff                                                             700020.0
# mutton                                                            10736.0
# chevon                                                           262332.0
# ...

# %% [markdown]
# **12. Filtration of Data Through District**

# %%
province_1 = ['BHOJPUR', 'DHANKUTA', 'ILAM', 'JHAPA', 'KHOTANG', 'MORANG', 'OKHALDHUNGA', 'PANCHTHAR', 'SANKHUWASABHA', 'SOLUKHUMBU', 'SUNSARI', 'TAPLEJUNG', 'TERHATHUM', 'UDAYAPUR']

province_2 = ['BARA', 'DHANUSA', 'MAHOTTARI', 'PARSA', 'RAUTAHAT', 'SAPTARI', 'SARLAHI', 'SIRAHA']

province_3 = ['BHAKTAPUR', 'CHITWAN', 'DHADING', 'DOLAKHA', 'KATHMANDU', 'KAVREPALANCHOK', 'LALITPUR', 'MAKWANPUR', 'NUWAKOT', 'RAMECHHAP', 'RASUWA', 'SINDHULI', 'SINDHUPALCHOK']

province_4 = ['BAGLUNG', 'GORKHA', 'KASKI', 'LAMJUNG', 'MANANG', 'MUSTANG', 'MYAGDI', 'NAWALPUR', 'PARBAT', 'SYANGJA', 'TANAHUN']

province_5 = ['ARGHAKHANCHI', 'BANKE', 'BARDIYA', 'DANG' , 'GULMI', 'KAPILVASTU', 'PALPA', 'NAWALPARASI', 'PYUTHAN', 'ROLPA', 'RUPANDEHI']

province_6 = ['DAILEKH', 'DOLPA', 'HUMLA', 'JAJARKOT', 'JUMLA', 'KALIKOT', 'MUGU', 'SALYAN', 'SURKHET', 'RUKUM']

province_7 = ['ACHHAM', 'BAITADI', 'BAJHANG', 'BAJURA', 'DADELDHURA', 'DARCHULA', 'DOTI', 'KAILALI', 'KANCHANPUR']

districts_of_nepal = province_1 + province_2 + province_3 + province_4 + province_5 + province_6 + province_7

# %%
# Filter rows based on districts_of_nepal
cleaned_df = cleaned_df[cleaned_df['district'].isin(districts_of_nepal)]
cleaned_df.reset_index(drop=True, inplace=True)

# %%
cleaned_df.sum()
# Out:
# district                ACHHAMARGHAKHANCHIBAGLUNGBAITADIBAJHANGBAJURAB...
# area_(ha)                                                           143.0
# prod_(mt)                                                           127.0
# yield_kg/ha                                                        3419.0
# horses/asses                                                      51539.0
# milking_cows_no                                                  901719.0
# milking_buffaloes_no                                            1186137.0
# cow_milk                                                         561873.0
# buff_milk                                                       1025748.0
# total_milk_produced                                             1587620.0
# buff                                                             155978.0
# mutton                                                             2589.0
# chevon                                                            59080.0
# ...

# %% [markdown]
# **13. Removing Outliers**

# %%
# Function to remove outliers
def remove_outliers(df, threshold=3):
    # Initialize a boolean mask to mark outliers
    outlier_mask = np.full(df.shape[0], False, dtype=bool)

    # Iterate over columns
    for column in df.columns:
        if df[column].dtype != 'object':  # Exclude non-numeric columns
            # Calculate the mean and standard deviation of the column
            mean = df[column].mean()
            std = df[column].std()

            # Mark outliers based on the threshold
            outlier_mask |= (df[column] < mean - threshold * std) | (df[column] > mean + threshold * std)

    # Return DataFrame without outliers
    return df[~outlier_mask]

# %%
# Remove outliers
cleaned_df = remove_outliers(cleaned_df)
cleaned_df.reset_index(drop=True, inplace=True)

# %%
cleaned_df.head()
# Out:
#        district  area_(ha)  prod_(mt)  yield_kg/ha  horses/asses  \
# 0        ACHHAM        0.0        0.0          0.0          95.0
# 1  ARGHAKHANCHI        0.0        0.0          0.0          17.0
# 2       BAGLUNG        0.0        0.0          0.0        1250.0
# 3       BAITADI        0.0        0.0          0.0         484.0
# 4       BAJHANG        0.0        0.0          0.0         724.0
#
#    milking_cows_no  milking_buffaloes_no  cow_milk  buff_milk  \
# 0           5796.0               10381.0    3321.0     9010.0
# 1           6219.0               27698.0    3805.0    25232.0
# 2           8950.0               22929.0    5128.0    18093.0
# 3           9845.0               12699.0    4641.0    10184.0
# 4          15936.0                9679.0    4600.0     4149.0
#
#    total_milk_produced  ...  total_meat  laying_hen  laying_duck  hen_egg  \
# 0              12331.0  ...      2102.0     12096.0        143.0   1905.0
# ...

# %%
cleaned_df.head()
# Out:
#        district  area_(ha)  prod_(mt)  yield_kg/ha  horses/asses  \
# 0        ACHHAM        0.0        0.0          0.0          95.0
# 1  ARGHAKHANCHI        0.0        0.0          0.0          17.0
# 2       BAGLUNG        0.0        0.0          0.0        1250.0
# 3       BAITADI        0.0        0.0          0.0         484.0
# 4       BAJHANG        0.0        0.0          0.0         724.0
#
#    milking_cows_no  milking_buffaloes_no  cow_milk  buff_milk  \
# 0           5796.0               10381.0    3321.0     9010.0
# 1           6219.0               27698.0    3805.0    25232.0
# 2           8950.0               22929.0    5128.0    18093.0
# 3           9845.0               12699.0    4641.0    10184.0
# 4          15936.0                9679.0    4600.0     4149.0
#
#    total_milk_produced  ...  total_meat  laying_hen  laying_duck  hen_egg  \
# 0              12331.0  ...      2102.0     12096.0        143.0   1905.0
# ...

# %%
# Replace NaN with 0
cleaned_df = cleaned_df.fillna(0)

# Check for NaN values
print(cleaned_df.isna().sum())
# Out:
# district                0
# area_(ha)               0
# prod_(mt)               0
# yield_kg/ha             0
# horses/asses            0
# milking_cows_no         0
# milking_buffaloes_no    0
# cow_milk                0
# buff_milk               0
# total_milk_produced     0
# buff                    0
# mutton                  0
# chevon                  0
# pork_                   0
# chicken                 0
# duck_meat               0
# total_meat              0
# laying_hen              0
# laying_duck             0
# hen_egg                 0
# duck_egg                0
# total_egg               0
# rabbit                  0
# sheeps_no               0
# sheep_wool_produced     0
# yak/nak/chauri          0
# dtype: int64

# %% [markdown]
# **14. Visualization of Cleaned Data**

# %% [markdown]
# **14.1. Scattter Plot**

# %%
plt.figure(figsize=(25, 5))
plt.scatter(cleaned_df['milking_buffaloes_no'],cleaned_df['milking_cows_no'], color='green', alpha=1)
plt.xlabel('Milking Cows')
plt.ylabel('Milking Buffaloes')
plt.title('Relationship between Milking Cows and Buffaloes')
plt.grid(True)
plt.show()

# %% [markdown]
# **14.2. Bar Chart**

# %%
plt.figure(figsize=(25, 5))
plt.bar(cleaned_df['district'], cleaned_df['milking_buffaloes_no'], color='red', alpha=0.5, label='Milking Buffaloes')
plt.bar(cleaned_df['district'], cleaned_df['milking_cows_no'], color='blue', alpha=0.5, label='Milking Cows')
plt.xlabel('District')
plt.ylabel('Number of Animals')
plt.title('Number of Milking Cows and Buffaloes by District')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# **14.3. Box Plot**

# %%
plt.figure(figsize=(25, 5))

box = plt.boxplot(
    [cleaned_df['cow_milk'], cleaned_df['buff_milk'], cleaned_df['total_milk_produced']],
    labels=['Cow Milk', 'Buffalo Milk', 'Total Milk Produced'],
    patch_artist=True
)

colors = ['#87CEFA', '#4682B4', '#1E90FF']  # light blue → steel blue → dodger blue
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

plt.title('Distribution of Milk Production')
plt.ylabel('Milk Production')
plt.show()
# Out:
# /tmp/ipython-input-1018551641.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box = plt.boxplot(

# %% [markdown]
# **14.5. Line Plot**

# %%
plt.figure(figsize=(25, 5))
plt.plot(cleaned_df['district'], cleaned_df['total_milk_produced'], marker='o', color='blue')
plt.xlabel('District')
plt.title('Total Milk Produced by District')
plt.ylabel('Total Milk Produced')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %% [markdown]
# **14.5. Corelation Heatmap**

# %%
plt.figure(figsize=(30, 8))
corr_matrix = merged_df.select_dtypes(include=[np.number]).corr()

# Using Reds colormap (sequential red shades)
sns.heatmap(corr_matrix, annot=True, cmap="Reds", center=0)
plt.title('Correlation Heatmap (Red Shades)')
plt.show()

# %% [markdown]
# **15.  Calculation of Average of Milk Production**

# %%
average_cow_milk_production = cleaned_df['cow_milk'].mean()
print("Average cow milk production:", round(average_cow_milk_production, 2))
# Out:
# Average cow milk production: 7407.26

# %%
districts_above_average = cleaned_df[cleaned_df['cow_milk'] >= average_cow_milk_production]

print("Districts where cow milk production is equal to or more than the average:")
print(districts_above_average[['district', 'cow_milk']])

count_districts_above_average = len(districts_above_average)
print("Number of districts where cow milk production is equal to or more than the average:", count_districts_above_average)
# Out:
# Districts where cow milk production is equal to or more than the average:
#        district  cow_milk
# 6         BANKE    8956.0
# 7          BARA   11952.0
# 8       BARDIYA   10792.0
# 14      DHADING   13791.0
# 15     DHANKUTA    8176.0
# 18         DOTI    7843.0
# 19       GORKHA    7653.0
# 21      KAILALI   27905.0
# 23   KANCHANPUR   23146.0
# 24        KASKI    9782.0
# 29    MAHOTTARI    9661.0
# 30    MAKWANPUR   12440.0
# 34  NAWALPARASI   18451.0
# 35      NUWAKOT   12234.0
# 38    PANCHTHAR    8511.0
# 44     RAUTAHAT   13162.0
# 46    RUPANDEHI   12120.0
# 49      SAPTARI   16654.0
# 50      SARLAHI   15374.0
# 51     SINDHULI    8024.0
# 53       SIRAHA    8125.0
# 55    TERHATHUM   10089.0
# 56     UDAYAPUR    9092.0
# Number of districts where cow milk production is equal to or more than the average: 23

# %%
average_milk_production = (cleaned_df["total_milk_produced"]).mean()
print("Average cow and buffalo milk production:", round(average_milk_production, 2))
# Out:
# Average cow and buffalo milk production: 21353.51

# %%
average_milk_production = cleaned_df[cleaned_df['total_milk_produced'] >= average_milk_production]

print("Districts where cow and buffalo milk production is equal to or more than the average:")
print(average_milk_production[['district', 'total_milk_produced']])

count_average_milk_production = len(average_milk_production)
print("Number of districts where cow milk production is equal to or more than the average:", count_average_milk_production)
# Out:
# Districts where cow and buffalo milk production is equal to or more than the average:
#          district  total_milk_produced
# 1    ARGHAKHANCHI              29037.0
# 2         BAGLUNG              23221.0
# 6           BANKE              40018.0
# 7            BARA              34690.0
# 8         BARDIYA              38576.0
# 10        BHOJPUR              21508.0
# 14        DHADING              38207.0
# 21        KAILALI              64582.0
# 23     KANCHANPUR              49022.0
# 24          KASKI              41016.0
# 29      MAHOTTARI              28108.0
# 30      MAKWANPUR              43214.0
# 34    NAWALPARASI              52047.0
# 35        NUWAKOT              31171.0
# 37          PALPA              28402.0
# 44       RAUTAHAT              28531.0
# 46      RUPANDEHI              38613.0
# 49        SAPTARI              41882.0
# 50        SARLAHI              33199.0
# 52  SINDHUPALCHOK              25023.0
# 53         SIRAHA              33749.0
# ...

# %% [markdown]
# **16. Adding Provinces**

# %% [markdown]
# **16.1. Changing of Dataset into Provinces**

# %%
district_to_province = {
    'Province 1': province_1,
    'Province 2': province_2,
    'Province 3': province_3,
    'Province 4': province_4,
    'Province 5': province_5,
    'Province 6': province_6,
    'Province 7': province_7
}

# %% [markdown]
# **16.2. Assigning Provinces**

# %%
# Function to assign provinces to districts
def assign_province(district):
    for province, districts in district_to_province.items():
        if district in districts:
            return province
    return None

# %% [markdown]
# **16.3. Adding New Column of Province**

# %%
cleaned_df['province'] = cleaned_df['district'].apply(assign_province)

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   district              57 non-null     object
#  1   area_(ha)             57 non-null     float64
#  2   prod_(mt)             57 non-null     float64
#  3   yield_kg/ha           57 non-null     float64
#  4   horses/asses          57 non-null     float64
#  5   milking_cows_no       57 non-null     float64
#  6   milking_buffaloes_no  57 non-null     float64
#  7   cow_milk              57 non-null     float64
#  8   buff_milk             57 non-null     float64
#  9   total_milk_produced   57 non-null     float64
#  10  buff                  57 non-null     float64
#  11  mutton                57 non-null     float64
#  12  chevon                57 non-null     float64
#  13  pork_                 57 non-null     float64
# ...

# %% [markdown]
# **16.4. Groupping Data By Province**

# %%
# Group the data by province and sum the numerical columns
province_df = cleaned_df.groupby('province').sum()

province_df.reset_index(inplace=True)

province_df.to_csv('province_data.csv', index=False)
province_df
# Out:
#      province                                           district  area_(ha)  \
# 0  Province 1  BHOJPURDHANKUTAKHOTANGOKHALDHUNGAPANCHTHARSANK...        0.0
# 1  Province 2     BARAMAHOTTARIPARSARAUTAHATSAPTARISARLAHISIRAHA        0.0
# 2  Province 3  BHAKTAPURDHADINGDOLAKHAKATHMANDULALITPURMAKWAN...        0.0
# 3  Province 4  BAGLUNGGORKHAKASKILAMJUNGMANANGMUSTANGMYAGDIPA...        0.0
# 4  Province 5  ARGHAKHANCHIBANKEBARDIYAGULMINAWALPARASIPALPAP...        0.0
# 5  Province 6                          DAILEKHDOLPAKALIKOTSALYAN        0.0
# 6  Province 7  ACHHAMBAITADIBAJHANGBAJURADADELDHURADARCHULADO...        0.0
#
#    prod_(mt)  yield_kg/ha  horses/asses  milking_cows_no  \
# 0        0.0          0.0        2480.0         105278.0
# 1        0.0          0.0         503.0         126969.0
# 2        0.0          0.0         950.0         114057.0
# 3        0.0          0.0        6489.0          50421.0
# 4        0.0          0.0        4892.0         122352.0
# ...

# %% [markdown]
# **17. Splitting of Dataset into Training and Testing**

# %%
# Function to split the data into training and testing sets
def split_data(cleaned_df, features, target_column, test_size=0.2, random_state=42):
    X = cleaned_df[features]
    y = cleaned_df[target_column]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    return X_train, X_test, y_train, y_test

# Features and target column
features = ['milking_buffaloes_no','milking_cows_no']
target_column = 'total_milk_produced'

# Split the data
X_train, X_test, y_train, y_test = split_data(cleaned_df, features, target_column)

# %% [markdown]
# **17.1. Vizualiztion of Splitted Data**

# %%
plt.scatter(X_train['milking_cows_no'], y_train, color='red', label='Training data (Buffaloes)')
plt.scatter(X_train['milking_buffaloes_no'], y_train, color='blue', label='Training data (Cows)')
plt.xlabel('Number of Animals')
plt.ylabel('Total Milk Produced')
plt.title('Number of Animals vs. Total Milk Produced (Training Data)')
plt.legend()
plt.show()

# %%
# Visualize the testing data
plt.scatter(X_test['milking_cows_no'], y_test, color='purple', label='Testing data (Buffaloes)')
plt.scatter(X_test['milking_buffaloes_no'], y_test, color='red', label='Testing data (Cows)')
plt.xlabel('Number of Animals')
plt.ylabel('Total Milk Produced')
plt.title(' Number of Animals vs. Total Milk Produced (Testing Data)')
plt.legend()
plt.show()

# %% [markdown]
# **18.Output of Models**

# %% [markdown]
# **18.1. Linear Regression**

# %%
# Instantiate the linear regression model
model = LinearRegression()

# Fit the model on the training data
model.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = model.predict(X_test)

# %%
sns.scatterplot(y_pred)
# Out:
# <Axes: >

# %% [markdown]
# **18.2. Vizualization of Predicted Data**

# %%
# Plot actual vs predicted values
plt.scatter(y_test, y_pred, color='green')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='black')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.grid(True)
plt.tight_layout()
plt.savefig('actual_vs_predicted.png')
plt.show()

# %% [markdown]
# **18.3. Calculation of Mean Squareed Error**

# %%
#  Mean Squared Error (MSE) calculation:
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)

# Plotting the predicted values against the actual values
plt.figure(figsize=(7, 5))
plt.scatter(y_test, y_pred, color='yellow', label='Predicted')
plt.plot(y_test, y_test, color='blue', linestyle='--', label='Actual')
plt.title('Model Outputs on Test Dataset')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean Squared Error (MSE): 45716587.22560871

# %% [markdown]
# **18.4. Calculation Mean Absolute Error**

# %%
#  Mean Absolute Error (MAE)calculation:
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error (MAE):", mae)

# Plotting the predicted values against the actual values
plt.figure(figsize=(7, 5))
plt.scatter(y_test, y_pred, color='red', label='Predicted')
plt.plot(y_test, y_test, color='purple', linestyle='--', label='Actual')
plt.title('Model Outputs on Test Dataset')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean Absolute Error (MAE): 4852.213855529612

# %% [markdown]
# **18.5. Visualization of Actual VS Predicted Data**

# %%
plt.figure(figsize=(7, 5))
plt.scatter(y_test, y_pred, color='red', label='Predicted')
plt.plot(y_test, y_test, color='purple', linestyle='--', label='Actual')  # reference line
plt.title('Model Outputs on Test Dataset')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **19.Cleaned Dataset**

# %%
from google.colab import files
cleaned_df.to_csv('cleaned_df.csv', index=False)
files.download('cleaned_df.csv')
